# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.value_counts()
# Out:
# hotel         is_canceled  lead_time  arrival_date_year  arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  meal  country  market_segment  distribution_channel  is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  reserved_room_type  assigned_room_type  booking_changes  deposit_type  agent  company  days_in_waiting_list  customer_type    adr     required_car_parking_spaces  total_of_special_requests  reservation_status  reservation_status_date
# ...

# %%
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
# Count the unique values in a column
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
# Checking the unique values in a column
df['reservation_status'].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %%
df['reservation_status'].nunique()
# Out:
# 3

# %% [markdown]
# Finding and Droping Duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(31994)

# %%
df.duplicated().value_counts(normalize =True)
# Out:
# False    0.732021
# True     0.267979
# Name: proportion, dtype: float64

# %%
# Get all duplicate rows
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 39      Resort Hotel            0         70               2015
# ...              ...          ...        ...                ...
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119372    City Hotel            0        175               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handling Missing values Pandas

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df[["agent", "country", "company", "children"]]
# Out:
#         agent country  company  children
# 0         NaN     PRT      NaN       0.0
# 1         NaN     PRT      NaN       0.0
# 2         NaN     GBR      NaN       0.0
# 3       304.0     GBR      NaN       0.0
# 4       240.0     GBR      NaN       0.0
# ...       ...     ...      ...       ...
# 119385  394.0     BEL      NaN       0.0
# 119386    9.0     FRA      NaN       0.0
# 119387    9.0     DEU      NaN       0.0
# 119388   89.0     GBR      NaN       0.0
# 119389    9.0     DEU      NaN       0.0
#
# [87396 rows x 4 columns]

# %%
children_mode = df.children.mode()[0]
print('children Mode   : ', children_mode)
# Out:
# children Mode   :  0.0

# %%
df['children'] = df['children'].replace(np.nan, children_mode)

# %%
df["children"].isnull().sum()
# Out:
# np.int64(0)

# %%
df['company'] = df['company'].fillna(0)

# %%
df['country'] = df['country'].fillna('Unknown')

# %%
df['agent'] = df['agent'].fillna(0)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# Hnadling missing values using Scikit-learn

# %%
df2 = pd.read_csv('hotel_bookings.csv')
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value=0)
df2[['agent']] = imputer.fit_transform(df2[['agent']])

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df2['children'] = imputer.fit_transform(df2[['children']])

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value=0)
df2['company'] = imputer.fit_transform(df2[['company']])

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value='unknown')
#df2['country'] = imputer.fit_transform(df2[['country']])
df2['country'] = imputer.fit_transform(df2[['country']]).ravel()

# %%
df2.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# Removing unnecessary row

# %%
# Remove records where adults, children, and babies are all 0
df = df[~((df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0))]

# %%
# Remove records with first-time guests who have previous booking history
df = df[~((df['is_repeated_guest'] == 0) & ((df['previous_cancellations'] > 0) | (df['previous_bookings_not_canceled'] > 0)))]

# %%
# Remove records where the number of adults is 0 but a parking space is requested
df = df[~((df['adults'] == 0) & (df['required_car_parking_spaces'] > 0))]

# %% [markdown]
# Creating New Features

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Create a new feature for total nights stayed
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# Create a new feature for total guests
df['total_guests'] = df['adults'] + df['children'] + df['babies']

# Display the first few rows with new features
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %% [markdown]
# Converting Data Type

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# Maping month names to numeric values
month_mapping = {
    "January": 1, "February": 2, "March": 3, "April": 4, "May": 5, "June": 6,
    "July": 7, "August": 8, "September": 9, "October": 10, "November": 11, "December": 12
}

df['arrival_date_month'] = df['arrival_date_month'].map(month_mapping)
df['arrival_date_month']
# Out:
# 0         7
# 1         7
# 2         7
# 3         7
# 4         7
#          ..
# 119385    8
# 119386    8
# 119387    8
# 119388    8
# 119389    8
# Name: arrival_date_month, Length: 85536, dtype: int64

# %%
# Convert the 'children' from float to int
df['children'] = df['children'].astype(int)
print(df['children'].dtypes)
# Out:
# int64

# %%
# Convert 'reservation_status_date' to datetime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# Convert 'agent' and 'company' columns from float to int to str
df['agent'] = df['agent'].astype(int).astype(str)
df['company'] = df['company'].astype(int).astype(str)

print(df[['agent', 'company']].dtypes)
# Out:
# agent      object
# company    object
# dtype: object

# %%
# Extract categorical/string variables
cat_cols = df.select_dtypes(include=['object']).columns
# Extract numerical variables
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
df[cat_cols]
# Out:
#                hotel meal country market_segment distribution_channel  \
# 0       Resort Hotel   BB     PRT         Direct               Direct
# 1       Resort Hotel   BB     PRT         Direct               Direct
# 2       Resort Hotel   BB     GBR         Direct               Direct
# 3       Resort Hotel   BB     GBR      Corporate            Corporate
# 4       Resort Hotel   BB     GBR      Online TA                TA/TO
# ...              ...  ...     ...            ...                  ...
# 119385    City Hotel   BB     BEL  Offline TA/TO                TA/TO
# 119386    City Hotel   BB     FRA      Online TA                TA/TO
# 119387    City Hotel   BB     DEU      Online TA                TA/TO
# 119388    City Hotel   BB     GBR      Online TA                TA/TO
# 119389    City Hotel   HB     DEU      Online TA                TA/TO
#
#        reserved_room_type assigned_room_type deposit_type agent company  \
# ...

# %%
df[num_cols]
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0                 0        342               2015                   7
# 1                 0        737               2015                   7
# 2                 0          7               2015                   7
# 3                 0         13               2015                   7
# 4                 0         14               2015                   7
# ...             ...        ...                ...                 ...
# 119385            0         23               2017                   8
# 119386            0        102               2017                   8
# 119387            0         34               2017                   8
# 119388            0        109               2017                   8
# 119389            0        205               2017                   8
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# ...

# %%
df[num_cols].describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  arrival_date_month  \
# count  85536.000000  85536.000000       85536.000000        85536.000000
# mean       0.269255     79.490308        2016.222316            6.454744
# std        0.443575     85.365339           0.680336            3.086923
# min        0.000000      0.000000        2015.000000            1.000000
# 25%        0.000000     12.000000        2016.000000            4.000000
# 50%        0.000000     49.000000        2016.000000            7.000000
# 75%        1.000000    124.000000        2017.000000            9.000000
# max        1.000000    737.000000        2017.000000           12.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              85536.000000               85536.000000
# mean                  26.745604                  15.817784
# std                   13.628040                   8.832327
# min                    1.000000                   1.000000
# ...

# %%
df[cat_cols].describe()
# Out:
#              hotel   meal country market_segment distribution_channel  \
# count        85536  85536   85536          85536                85536
# unique           2      5     178              8                    5
# top     City Hotel     BB     PRT      Online TA                TA/TO
# freq         52455  66451   26051          50995                67972
#
#        reserved_room_type assigned_room_type deposit_type  agent company  \
# count               85536              85536        85536  85536   85536
# unique                  9                 10            3    334     346
# top                     A                  A   No Deposit      9       0
# freq                55142              45303        84607  28450   80632
#
#        customer_type reservation_status
# count          85536              85536
# unique             4                  3
# top        Transient          Check-Out
# freq           70709              62505

# %%
df['arrival_date_year'].describe()
# Out:
# count    85536.000000
# mean      2016.222316
# std          0.680336
# min       2015.000000
# 25%       2016.000000
# 50%       2016.000000
# 75%       2017.000000
# max       2017.000000
# Name: arrival_date_year, dtype: float64

# %% [markdown]
# Renaming Column name for better understanding

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_nights',
#        'total_guests'],
#       dtype='object')

# %%
df.rename(columns={'hotel': 'hotel_name'}, inplace=True)
df.rename(columns={'is_canceled': 'canceled'}, inplace=True)
df.rename(columns={'arrival_date_year': 'arriving_year'}, inplace=True)
df.rename(columns={'arrival_date_week_number': 'arriving_week'}, inplace=True)
df.rename(columns={'arrival_date_day_of_month': 'arriving_month'}, inplace=True)
df.rename(columns={'is_repeated_guest': 'Repeated_Guest'}, inplace=True)
df.rename(columns={'adr': 'average_daily_rate'}, inplace=True)

# %%
df.head()
# Out:
#      hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 0  Resort Hotel         0        342           2015                   7
# 1  Resort Hotel         0        737           2015                   7
# 2  Resort Hotel         0          7           2015                   7
# 3  Resort Hotel         0         13           2015                   7
# 4  Resort Hotel         0         14           2015                   7
#
#    arriving_week  arriving_month  stays_in_weekend_nights  \
# 0             27               1                        0
# 1             27               1                        0
# 2             27               1                        0
# 3             27               1                        0
# 4             27               1                        0
#
#    stays_in_week_nights  adults  ...  company  days_in_waiting_list  \
# 0                     0       2  ...        0                     0
# ...

# %% [markdown]
# Slicing Dataframe

# %%
#loc is used to select rows and columns by label
#df2.loc[1:5]
df2.loc[1:3, ['hotel', 'lead_time']]
# Out:
#           hotel  lead_time
# 1  Resort Hotel        737
# 2  Resort Hotel          7
# 3  Resort Hotel         13

# %%
#iloc is used to select rows and columns by integer position:
df2.iloc[1:5, [0,2]]
# Out:
#           hotel  lead_time
# 1  Resort Hotel        737
# 2  Resort Hotel          7
# 3  Resort Hotel         13
# 4  Resort Hotel         14

# %% [markdown]
# Querying dataframe

# %%
df[df.stays_in_week_nights > 30]
# Out:
#          hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 1655   Resort Hotel         0         30           2015                   9
# 9839   Resort Hotel         1        322           2017                   1
# 14037  Resort Hotel         0        113           2015                   8
# 32589  Resort Hotel         0          1           2017                   2
# 33924  Resort Hotel         0         71           2017                   1
# 54704    City Hotel         0        206           2016                   7
#
#        arriving_week  arriving_month  stays_in_weekend_nights  \
# 1655              37               7                       13
# 9839               2              10                       16
# 14037             31               1                       18
# 32589              5               3                       13
# 33924              2              10                       16
# ...

# %%
df[df.stays_in_week_nights < 20][['hotel_name', 'lead_time']]
# Out:
#           hotel_name  lead_time
# 0       Resort Hotel        342
# 1       Resort Hotel        737
# 2       Resort Hotel          7
# 3       Resort Hotel         13
# 4       Resort Hotel         14
# ...              ...        ...
# 119385    City Hotel         23
# 119386    City Hotel        102
# 119387    City Hotel         34
# 119388    City Hotel        109
# 119389    City Hotel        205
#
# [85460 rows x 2 columns]

# %%
df[(df.hotel_name == 'City Hotel') & (df.children > 3)]
# Out:
# Empty DataFrame
# Columns: [hotel_name, canceled, lead_time, arriving_year, arrival_date_month, arriving_week, arriving_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, Repeated_Guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, average_daily_rate, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, total_nights, total_guests]
# Index: []
#
# [0 rows x 34 columns]

# %%
df.query('lead_time > 700')
# Out:
#         hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 1     Resort Hotel         0        737           2015                   7
# 4182  Resort Hotel         0        709           2016                   2
#
#       arriving_week  arriving_month  stays_in_weekend_nights  \
# 1                27               1                        0
# 4182              9              25                        8
#
#       stays_in_week_nights  adults  ...  company  days_in_waiting_list  \
# 1                        0       2  ...        0                     0
# 4182                    20       2  ...        0                     0
#
#      customer_type average_daily_rate required_car_parking_spaces  \
# 1        Transient                0.0                           0
# 4182     Transient               68.0                           0
#
#      total_of_special_requests  reservation_status  reservation_status_date  \
# ...

# %%
df.query('hotel_name == "Resort Hotel"')
# Out:
#          hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 0      Resort Hotel         0        342           2015                   7
# 1      Resort Hotel         0        737           2015                   7
# 2      Resort Hotel         0          7           2015                   7
# 3      Resort Hotel         0         13           2015                   7
# 4      Resort Hotel         0         14           2015                   7
# ...             ...       ...        ...            ...                 ...
# 40055  Resort Hotel         0        212           2017                   8
# 40056  Resort Hotel         0        169           2017                   8
# 40057  Resort Hotel         0        204           2017                   8
# 40058  Resort Hotel         0        211           2017                   8
# 40059  Resort Hotel         0        161           2017                   8
#
# ...

# %%
df.query('lead_time > 700 and stays_in_weekend_nights > 4')
# Out:
#         hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 4182  Resort Hotel         0        709           2016                   2
#
#       arriving_week  arriving_month  stays_in_weekend_nights  \
# 4182              9              25                        8
#
#       stays_in_week_nights  adults  ...  company  days_in_waiting_list  \
# 4182                    20       2  ...        0                     0
#
#      customer_type average_daily_rate required_car_parking_spaces  \
# 4182     Transient               68.0                           0
#
#      total_of_special_requests  reservation_status  reservation_status_date  \
# 4182                         0           Check-Out               2016-03-24
#
#       total_nights total_guests
# 4182            28          2.0
#
# [1 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['hotel_name', 'canceled', 'lead_time', 'arriving_year',
#        'arrival_date_month', 'arriving_week', 'arriving_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'market_segment', 'distribution_channel',
#        'Repeated_Guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type',
#        'average_daily_rate', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date', 'total_nights', 'total_guests'],
#       dtype='object')

# %%
df.query('adults > 4 and babies < 2')
# Out:
#         hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 1539  Resort Hotel         1        304           2015                   9
# 1587  Resort Hotel         1        333           2015                   9
# 1643  Resort Hotel         1        336           2015                   9
# 1752  Resort Hotel         1        340           2015                   9
# 1884  Resort Hotel         1        347           2015                   9
# 1917  Resort Hotel         1        349           2015                   9
# 1962  Resort Hotel         1        352           2015                   9
# 2003  Resort Hotel         1        354           2015                   9
# 2164  Resort Hotel         1        361           2015                  10
# 2173  Resort Hotel         1        338           2015                  10
# 2228  Resort Hotel         1        328           2015                  10
# ...

# %%
df.sort_index(ascending = False)
# Out:
#           hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 119389    City Hotel         0        205           2017                   8
# 119388    City Hotel         0        109           2017                   8
# 119387    City Hotel         0         34           2017                   8
# 119386    City Hotel         0        102           2017                   8
# 119385    City Hotel         0         23           2017                   8
# ...              ...       ...        ...            ...                 ...
# 4       Resort Hotel         0         14           2015                   7
# 3       Resort Hotel         0         13           2015                   7
# 2       Resort Hotel         0          7           2015                   7
# 1       Resort Hotel         0        737           2015                   7
# 0       Resort Hotel         0        342           2015                   7
#
# ...

# %%
df.sort_values(by = 'arriving_year')
# Out:
#           hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 15      Resort Hotel         0         68           2015                   7
# 14      Resort Hotel         0         37           2015                   7
# 13      Resort Hotel         0         18           2015                   7
# 12      Resort Hotel         0         68           2015                   7
# 11      Resort Hotel         0         35           2015                   7
# ...              ...       ...        ...            ...                 ...
# 119385    City Hotel         0         23           2017                   8
# 119386    City Hotel         0        102           2017                   8
# 119387    City Hotel         0         34           2017                   8
# 119388    City Hotel         0        109           2017                   8
# 119389    City Hotel         0        205           2017                   8
#
# ...

# %%
df.sort_values(by = 'arriving_year', ascending = False)
# Out:
#           hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 119374    City Hotel         0        201           2017                   8
# 119372    City Hotel         0        175           2017                   8
# 119371    City Hotel         0        175           2017                   8
# 119370    City Hotel         0        201           2017                   8
# 119369    City Hotel         0        207           2017                   8
# ...              ...       ...        ...            ...                 ...
# 6       Resort Hotel         0          0           2015                   7
# 4       Resort Hotel         0         14           2015                   7
# 3       Resort Hotel         0         13           2015                   7
# 2       Resort Hotel         0          7           2015                   7
# 1       Resort Hotel         0        737           2015                   7
#
# ...

# %%
df.sort_values(by = ['arriving_year','arrival_date_month'])
# Out:
#           hotel_name  canceled  lead_time  arriving_year  arrival_date_month  \
# 0       Resort Hotel         0        342           2015                   7
# 1       Resort Hotel         0        737           2015                   7
# 2       Resort Hotel         0          7           2015                   7
# 3       Resort Hotel         0         13           2015                   7
# 4       Resort Hotel         0         14           2015                   7
# ...              ...       ...        ...            ...                 ...
# 119385    City Hotel         0         23           2017                   8
# 119386    City Hotel         0        102           2017                   8
# 119387    City Hotel         0         34           2017                   8
# 119388    City Hotel         0        109           2017                   8
# 119389    City Hotel         0        205           2017                   8
#
# ...

# %%
df.value_counts()
# Out:
# hotel_name    canceled  lead_time  arriving_year  arrival_date_month  arriving_week  arriving_month  stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  meal  country  market_segment  distribution_channel  Repeated_Guest  previous_cancellations  previous_bookings_not_canceled  reserved_room_type  assigned_room_type  booking_changes  deposit_type  agent  company  days_in_waiting_list  customer_type    average_daily_rate  required_car_parking_spaces  total_of_special_requests  reservation_status  reservation_status_date  total_nights  total_guests
# ...

# %%
df.canceled.value_counts()
# Out:
# canceled
# 0    62505
# 1    23031
# Name: count, dtype: int64

# %%
df.groupby('hotel_name').agg({'children': 'mean'})
# Out:
#               children
# hotel_name
# City Hotel    0.133391
# Resort Hotel  0.151446

# %%
df.groupby(by = 'hotel_name')['children'].mean()
# Out:
# hotel_name
# City Hotel      0.133391
# Resort Hotel    0.151446
# Name: children, dtype: float64

# %%
df.groupby(by = 'hotel_name')['children'].sum()
# Out:
# hotel_name
# City Hotel      6997
# Resort Hotel    5010
# Name: children, dtype: int64

# %%
df.groupby(by = 'hotel_name')['children'].max()
# Out:
# hotel_name
# City Hotel       3
# Resort Hotel    10
# Name: children, dtype: int64

# %% [markdown]
# Calculating customer at each hotel

# %%
df['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# 8     11094
# 7      9832
# 5      8285
# 4      7810
# 6      7684
# 3      7381
# 10     6671
# 9      6475
# 2      5988
# 12     4898
# 11     4847
# 1      4571
# Name: count, dtype: int64

# %%
# Monthly Number of Customers at Resort Hotel
resort_not_canceled = df[(df['hotel_name'] == 'Resort Hotel')].copy()

resort_guests = resort_not_canceled['arrival_date_month'].value_counts().reset_index()
resort_guests.columns=['month','num of guests']
resort_guests
# Out:
#     month  num of guests
# 0       8           4587
# 1       7           4215
# 2       5           2903
# 3       4           2766
# 4       6           2720
# 5      10           2647
# 6       3           2578
# 7       2           2414
# 8       9           2353
# 9      12           2023
# 10     11           1989
# 11      1           1886

# %%
# Monthly Number of Customers at City Hotel
resort_not_canceled = df[(df['hotel_name'] == 'City Hotel')].copy()

city_guests = resort_not_canceled['arrival_date_month'].value_counts().reset_index()
city_guests.columns=['month','num of guests']
city_guests
# Out:
#     month  num of guests
# 0       8           6507
# 1       7           5617
# 2       5           5382
# 3       4           5044
# 4       6           4964
# 5       3           4803
# 6       9           4122
# 7      10           4024
# 8       2           3574
# 9      12           2875
# 10     11           2858
# 11      1           2685

# %% [markdown]
# Calculate cancellation rate

# %%
total_bookings = len(df)
canceled_bookings = df['canceled'].sum()
cancellation_rate = (canceled_bookings / total_bookings) * 100
print(f"Cancellation Rate: {cancellation_rate:.2f}%")
# Out:
# Cancellation Rate: 26.93%
